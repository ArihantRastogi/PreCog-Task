# %% [markdown]
# # Task 2 and 3 - Generation and Bonus
# - This is the CRNN Model for the PreCog Task

# %% [markdown]
# ## Dependencies
#
# imports everything

# %%
import os
from PIL import Image, ImageDraw, ImageFont
import random
from random_word import RandomWords
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from torchvision import transforms

# %%
# 1000 random words for dataset, changed for this to make diverse words for character predictions from 100 in task 1 to 1000 in task 2
# will also reduce the number of images per word from 100 to 10, to prevent overfitting (checked by running the code for both the values, loss was higher for the 1000 word model, indicating less of an overfit)

def generate_random_words(num_words):
    r = RandomWords()
    words = []
    while len(words) < num_words:
        word = r.get_random_word()
        if word and 5 <= len(word) <= 9:
            words.append(word)

    return words

words = generate_random_words(1000)
print(words)
# Out:
# ['bumped', 'encinder', 'kuvaszok', 'butyrin', 'tabour', 'smirtle', 'discount', 'cosset', 'woolfells', 'exorcises', 'handsale', 'sighs', 'bookward', 'underhum', 'belesprit', 'filarious', 'curbline', 'hyporight', 'confed', 'shifts', 'tictoc', 'gnapweed', 'unplow', 'coercive', 'portsale', 'pogromist', 'deathworm', 'selenates', 'tuskar', 'button', 'surmising', 'stampeder', 'rancors', 'subungual', 'sixfolds', 'astre', 'meropic', 'senocular', 'runfish', 'vulpinism', 'unfusible', 'eyeserver', 'tamandu', 'cobus', 'upsweeps', 'praus', 'lester', 'ataractic', 'bowmaking', 'caraho', 'emissory', 'wambais', 'reaccuses', 'disna', 'atreptic', 'baggers', 'probits', 'shoved', 'precludes', 'gimmicks', 'boleros', 'gnatty', 'navarch', 'hamital', 'florida', 'sacatons', 'pieforts', 'tecali', 'uncrated', 'cirrosely', 'reddish', 'blowbys', 'mapach', 'remicate', 'typhosis', 'galravage', 'pitmen', 'tokays', 'astound', 'practicum', 'busks', 'mesotroch', 'baloneys', 'rashing', 'bugeyed', 'leegte', 'gutser', 'rosette', 'gourmet', 'racemism', 'insetters', 'striatum', 'canthi', 'frictions', 'recumbent', 'norwester', 'embrowned', 'seidels', 'antonymy', 'eozoonal', 'urushiye', 'skelp', 'acentric', 'defraying', 'stargazed', 'anthill', 'overhaul', 'meltwater', 'joannes', 'liturgist', 'puccinoid', 'gingals', 'bagwomen', 'muckrakes', 'gauming', 'comminute', 'handworm', 'coreigner', 'cleidagra', 'surcle', 'etcetera', 'suicided', 'cnidarian', 'ignobly', 'espontoon', 'lobulate', 'shieling', 'wanderoo', 'fazenda', 'furthest', 'spouse', 'brawniest', 'selectmen', 'collisive', 'archaise', 'maven', 'fogram', 'wicking', 'authigene', 'gravette', 'admirably', 'outheard', 'gambado', 'nonsystem', 'athrough', 'midairs', 'twitten', 'harmoot', 'heathier', 'catonic', 'bowralite', 'comicry', 'besmearer', 'eburnian', 'reinjures', 'conferrer', 'krimmers', 'daffy', 'enlaurel', 'testacea', 'manteel', 'chronaxia', 'cineast', 'reperplex', 'pantarbe', 'sunburns', 'giarre', 'longicone', 'bossy', 'apportion', 'anangular', 'asperite', 'saunters', 'seismisms', 'averaged', 'landsale', 'moqui', 'outcarry', 'insident', 'santii', 'boathead', 'knopite', 'unlegible', 'dookit', 'chametz', 'myxoinoma', 'dullhead', 'tyrannus', 'jadishly', 'lanthanid', 'toponymic', 'heikum', 'bharti', 'vibrion', 'pataka', 'debouches', 'hugoesque', 'advocaat', 'virulency', 'chende', 'umland', 'asterina', 'miter', 'sambuca', 'bullweed', 'kickable', 'galactose', 'disbend', 'benthonic', 'jellydom', 'myogram', 'dibhole', 'chassis', 'pameroon', 'fayal', 'blousiest', 'myxoid', 'preguide', 'contakia', 'gobby', 'foalfoot', 'lichenise', 'cutinized', 'nerts', 'achates', 'pavonated', 'leger', 'gests', 'oxtails', 'backups', 'wanweird', 'paddywack', 'retomb', 'apennine', 'polyzooid', 'punaluan', 'heroized', 'cipango', 'esture', 'nurselet', 'pedial', 'oxyrhine', 'desalters', 'inputting', 'hawseman', 'trapanner', 'spald', 'velarium', 'enostosis', 'islamism', 'fissura', 'mothered', 'molluscan', 'elinor', 'torch', 'diverter', 'enseating', 'neronian', 'inoculant', 'overslipt', 'spinules', 'ashir', 'mascotte', 'cardin', 'exporting', 'revestry', 'agudist', 'concent', 'teller', 'cithren', 'duckblind', 'sheetling', 'descried', 'vacoua', 'quill', 'alfaquins', 'mommy', 'cyanidin', 'columbier', 'wagework', 'hognuts', 'jobmen', 'lispound', 'destiny', 'inositols', 'proactive', 'urushiols', 'turfite', 'mucuses', 'salable', 'fimbriate', 'pacos', 'strayaway', 'oscarella', 'hematine', 'oceanlike', 'quilts', 'reapply', 'johnboats', 'randoms', 'zymoscope', 'forswear', 'sinawa', 'trinitro', 'varves', 'amylene', 'shicksas', 'apteryla', 'dodgery', 'wekas', 'switches', 'euonymy', 'eyebrow', 'cooty', 'rolamite', 'andric', 'wharl', 'senci', 'milksops', 'selenious', 'paralalia', 'isidium', 'overwide', 'peage', 'attorning', 'liquiform', 'coach', 'baronne', 'disserts', 'manit', 'peesweeps', 'bescurf', 'enfetters', 'morin', 'souhegan', 'perisarc', 'balsamer', 'pilpay', 'washbowl', 'curlyhead', 'shadfly', 'petitor', 'zeatins', 'danize', 'baiting', 'cougher', 'gau ...

# %%
# same as task 0

def add_noise(draw, width, height):
    for _ in range(random.randint(4000, 5000)):
        x, y = random.randint(0, width - 1), random.randint(0, height - 1)
        color = tuple(random.randint(0, 255) for _ in range(3))
        draw.point((x, y), fill=color)

FONTS = [
    "Fonts/akira.ttf",
    "Fonts/dejavu-sans-bold.ttf",
    "Fonts/Roboto-Italic.ttf",
    "Fonts/Roboto.ttf",
    "Fonts/Harabara.ttf",
    "Fonts/Designer.ttf",
    "Fonts/OpenSans-Italic.ttf",
    "Fonts/OpenSans-Regular.ttf"
]

def generate_hard_set():
    for i in range(0,10):
        for word in words:
            width, height = 248, 80
            # generate image with white only
            img = Image.new("RGB", (width, height), color="white")
            draw = ImageDraw.Draw(img)
            
            # generate fonts with random fonts and colors
            font = ImageFont.truetype(random.choice(FONTS), size = 30)
            text_color = tuple(random.randint(0, 255) for _ in range(3))
            
            # generate fonts with random capitalization
            word_variation = ''.join(random.choice([c.upper(), c.lower()]) for c in word)
            text_bbox = font.getbbox(word)
            text_width = text_bbox[2] - text_bbox[0]
            text_height = text_bbox[3] - text_bbox[1]

            position = ((width - text_width) // 2, (height - text_height) // 2)

            draw.text(position, word_variation, fill=text_color, font=font)

            # Add noise
            add_noise(draw, width, height)

            img.save(os.path.join("content/dataset/hard", f"{word}_{i}.png"))

generate_hard_set()

def generate_bonus_set():
    for i in range(0, 10):
        for word in words:
            width, height = 248, 80
            bg_color = random.randint(0, 1)
            if bg_color == 0 :
                bg = "green"
            else :
                bg = "red"

            img = Image.new("RGB", (width, height), color=bg)
            draw = ImageDraw.Draw(img)

            font = ImageFont.truetype(random.choice(FONTS), size=30)
            text_color = "black"

            word_variation = ''.join(random.choice([c.upper(), c.lower()]) for c in word)
            text_bbox = font.getbbox(word)
            text_width = text_bbox[2] - text_bbox[0]
            text_height = text_bbox[3] - text_bbox[1]

            position = ((width - text_width) // 2, (height - text_height) // 2)

            if bg_color == 1:
                final_word = word_variation [::-1]
            else :
                final_word = word_variation

            draw.text(position, final_word, fill=text_color, font=font)

            # Add noise
            add_noise(draw, width, height)

            img.save(os.path.join("content/dataset/bonus", f"{word}_{i}.png"))

generate_bonus_set()

# %%
# generating a single hard image for testing

def generate_hard_image(word):  
    width, height = 248, 80
    # generate image with white only
    img = Image.new("RGB", (width, height), color="white")
    draw = ImageDraw.Draw(img)
    
    # generate fonts with random fonts and colors
    font = ImageFont.truetype(random.choice(FONTS), size = 30)
    text_color = tuple(random.randint(0, 255) for _ in range(3))
    
    # generate fonts with random capitalization
    word_variation = ''.join(random.choice([c.upper(), c.lower()]) for c in word)
    text_bbox = font.getbbox(word)
    text_width = text_bbox[2] - text_bbox[0]
    text_height = text_bbox[3] - text_bbox[1]

    position = ((width - text_width) // 2, (height - text_height) // 2)

    draw.text(position, word_variation, fill=text_color, font=font)

    # Add noise
    add_noise(draw, width, height)

    img.save(f"{word}.png")

generate_hard_image(word = "arihant")

# %%
# generating a single bonus word for testing

def generate_bonus_image(word):  
    width, height = 248, 80
    bg_color = random.randint(0, 1)
    if bg_color == 0 :
        bg = "green"
    else :
        bg = "red"

    img = Image.new("RGB", (width, height), color=bg)
    draw = ImageDraw.Draw(img)

    font = ImageFont.truetype(random.choice(FONTS), size=30)
    text_color = "black"

    word_variation = ''.join(random.choice([c.upper(), c.lower()]) for c in word)
    text_bbox = font.getbbox(word)
    text_width = text_bbox[2] - text_bbox[0]
    text_height = text_bbox[3] - text_bbox[1]

    position = ((width - text_width) // 2, (height - text_height) // 2)

    if bg_color == 1:
        final_word = word_variation [::-1]
    else :
        final_word = word_variation

    draw.text(position, final_word, fill=text_color, font=font)

    add_noise(draw, width, height)

    img.save(f"{word}.png")

generate_bonus_image(word = "arihant")

# %%
# generating a single easy word for testing

def generate_image(word):  
    font_path = "Fonts/OpenSans-Regular.ttf"  
    width, height = 248, 80
    color = 255
    image = Image.new("L", (width, height), color)
    draw = ImageDraw.Draw(image)
    try:
        font = ImageFont.truetype(font_path, 36)
    except OSError as e:
        print(f"Error loading font: {e}")
        return
    text = word.title()
    text_bbox = font.getbbox(word)
    text_width = text_bbox[2] - text_bbox[0]
    text_height = text_bbox[3] - text_bbox[1]
    x = random.randint((width - text_width)//8, 7*((width - text_width)//8))
    y = random.randint((height - text_height)//8, 7*((height - text_height)//8))
    position = (x, y)
    text_color = 0
    draw.text(position, text, font=font, fill=text_color)
    image.save(f"{word}.png")

generate_image(word = "arihant")

# %% [markdown]
# ## Dataset and Collate function

# %%
def collate_fn(batch):
    images, labels, lengths = zip(*batch)
    
    images = torch.stack(images)

    # Find max label length in batch for padding
    max_len = max(lengths)
    padded_labels = torch.full((len(labels), max_len), fill_value=0, dtype=torch.long)

    for i, label in enumerate(labels):
        padded_labels[i, :len(label)] = label

    lengths = torch.tensor(lengths, dtype=torch.long)

    return images, padded_labels, lengths

class WordImageDataset(Dataset):
    def __init__(self, image_dir, transform=None):
        self.image_dir = image_dir
        self.transform = transform
        self.images = []
        self.labels = []
        self.label_to_idx = {'<blank>': 0}
        self.idx_to_label = {0: '<blank>'}
        
        chars = set()
        for filename in os.listdir(image_dir):
            if filename.endswith('.png'):
                word = filename.split('_')[0]
                chars.update(word)
        
        for idx, char in enumerate(sorted(chars), start=1):
            self.label_to_idx[char] = idx
            self.idx_to_label[idx] = char
        
        for filename in os.listdir(image_dir):
            if filename.endswith('.png'):
                word = filename.split('_')[0]
                char_indices = [self.label_to_idx[c] for c in word]
                self.images.append(os.path.join(image_dir, filename))
                self.labels.append(torch.tensor(char_indices, dtype=torch.long))

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image_path = self.images[idx]
        image = Image.open(image_path).convert('L')
        
        if self.transform:
            image = self.transform(image)
            
        label = self.labels[idx]
        length = len(label)
        
        return image, label, length

# %% [markdown]
# ## Architecture for CRNN Model

# %%
class CRNN(nn.Module):
    def __init__(self, num_classes, hidden_size=256):
        super(CRNN, self).__init__()
        
        self.cnn = nn.Sequential(
            nn.Conv2d(1, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            
            nn.Conv2d(128, 256, kernel_size=3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d((2, 1)),
            
            nn.Conv2d(256, hidden_size, kernel_size=3, padding=1),
            nn.BatchNorm2d(hidden_size),
            nn.ReLU()
        )
        
        self.rnn = nn.LSTM(hidden_size, hidden_size, bidirectional=True, batch_first=True)
        self.fc = nn.Linear(hidden_size * 2, num_classes)

    def forward(self, x):
        conv = self.cnn(x)
        # Reshape for RNN
        b, c, h, w = conv.size()
        conv = conv.view(b, c, -1)  # Merging h for 3D
        conv = conv.permute(0, 2, 1)

        # RNN and final prediction
        rnn, _ = self.rnn(conv)
        output = self.fc(rnn)

        return output

# %% [markdown]
# ## Training

# %%
def train_ocr_model(model, train_loader, criterion, optimizer, num_epochs=20, device='cuda'):
    model.to(device)
    for epoch in range(num_epochs):
        model.train()
        total_loss = 0
        
        for batch_idx, (images, targets, target_lengths) in enumerate(train_loader):
            images = images.to(device)
            targets = targets.to(device)
            target_lengths = target_lengths.to(device)
            
            optimizer.zero_grad()
            outputs = model(images)

            batch_size = outputs.size(0)
            input_lengths = torch.full((batch_size,), outputs.size(1), dtype=torch.long).to(device)

            # Computing CTC loss
            loss = criterion(outputs.log_softmax(2).permute(1, 0, 2), 
                             targets, input_lengths, target_lengths)
            
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
            
            if batch_idx % 10 == 0:
                print(f'Epoch [{epoch+1}/{num_epochs}], Batch [{batch_idx}/{len(train_loader)}], Loss: {loss.item():.4f}')
        
        avg_loss = total_loss / len(train_loader)
        print(f'Epoch [{epoch+1}/{num_epochs}], Average Loss: {avg_loss:.4f}')

    # Saving model to use it
    torch.save(model.state_dict(), "crnn_model.pth")
    print("Model saved successfully.")

# %% [markdown]
# ## Decoder for Prediction

# %%
def decode_predictions(outputs, idx_to_label):
    _, predictions = outputs.max(2)
    predictions = predictions.cpu().numpy()
    
    decoded_words = []
    for pred in predictions:
        word = []
        prev_idx = -1
        
        for idx in pred:
            if idx != 0 and idx != prev_idx: 
# Improved accuracy when i ran it multiple times by removing spaces and all (didnt formally test it but found good enough proof over a bunch of examples)
                word.append(idx_to_label[idx])
            prev_idx = idx
            
        decoded_words.append(''.join(word))
    
    return decoded_words

# %% [markdown]
# ## Testing function

# %%
def preprocess_image(image_path):
    transform = transforms.Compose([
        transforms.Resize((32, 128)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.5], std=[0.5])
    ])
    
    image = Image.open(image_path).convert('L') # can change for RGB but for my tests it was actually better when i forcefully converted to greyscale
    image = transform(image).unsqueeze(0)
    
    return image

def predict_image(model, image_path, idx_to_label, device='cuda'):
    model.to(device)
    model.eval()
    
    image = preprocess_image(image_path).to(device)

    with torch.no_grad():
        output = model(image)

    predicted_text = decode_predictions(output, idx_to_label)
    
    return predicted_text[0]

# %% [markdown]
# ## Main code

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

transform = transforms.Compose([
    transforms.Resize((32, 128)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5], std=[0.5])
])

dataset = WordImageDataset('content/dataset/easy', transform=transform)
train_loader = DataLoader(dataset, batch_size=32, shuffle=True, collate_fn=collate_fn)

model = CRNN(num_classes=len(dataset.label_to_idx))
criterion = nn.CTCLoss(zero_infinity=True)
optimizer = optim.Adam(model.parameters(), lr=0.001)

# train
train_ocr_model(model, train_loader, criterion, optimizer, device=device)

# load for test
model.load_state_dict(torch.load("crnn_model.pth"))
# Out:
# Epoch [1/20], Batch [0/623], Loss: 48.7920
# Epoch [1/20], Batch [10/623], Loss: 5.3036
# Epoch [1/20], Batch [20/623], Loss: 3.2787
# Epoch [1/20], Batch [30/623], Loss: 3.2456
# Epoch [1/20], Batch [40/623], Loss: 3.2499
# Epoch [1/20], Batch [50/623], Loss: 3.2310
# Epoch [1/20], Batch [60/623], Loss: 3.2166
# Epoch [1/20], Batch [70/623], Loss: 3.1425
# Epoch [1/20], Batch [80/623], Loss: 3.1011
# Epoch [1/20], Batch [90/623], Loss: 3.1990
# Epoch [1/20], Batch [100/623], Loss: 3.1897
# Epoch [1/20], Batch [110/623], Loss: 3.2132
# Epoch [1/20], Batch [120/623], Loss: 3.1245
# Epoch [1/20], Batch [130/623], Loss: 3.1723
# Epoch [1/20], Batch [140/623], Loss: 3.0769
# Epoch [1/20], Batch [150/623], Loss: 3.0377
# Epoch [1/20], Batch [160/623], Loss: 3.0797
# Epoch [1/20], Batch [170/623], Loss: 3.1376
# Epoch [1/20], Batch [180/623], Loss: 3.0886
# Epoch [1/20], Batch [190/623], Loss: 3.0754
# Epoch [1/20], Batch [200/623], Loss: 3.0622
# Epoch [1/20], Batch [210/623], Loss: 3.1038
# Epoch [1/20], Batch [220/623], Loss: 3.0901
# Epoch [1/20], Batch [230/623], Loss: 3.0856
# Epoch [1/20], Batch [240/623], Loss: 3.1049
# Epoch [1/20], Batch [250/623], Loss: 2.9976
# Epoch [1/20], Batch [260/623], Loss: 3.0837
# Epoch [1/20], Batch [270/623], Loss: 3.0951
# Epoch [1/20], Batch [280/623], Loss: 2.9671
# Epoch [1/20], Batch [290/623], Loss: 3.0278
# Epoch [1/20], Batch [300/623], Loss: 3.0910
# Epoch [1/20], Batch [310/623], Loss: 3.0483
# Epoch [1/20], Batch [320/623], Loss: 3.0412
# Epoch [1/20], Batch [330/623], Loss: 3.1045
# Epoch [1/20], Batch [340/623], Loss: 3.0011
# Epoch [1/20], Batch [350/623], Loss: 3.1210
# Epoch [1/20], Batch [360/623], Loss: 3.0594
# Epoch [1/20], Batch [370/623], Loss: 2.9646
# Epoch [1/20], Batch [380/623], Loss: 2.9970
# Epoch [1/20], Batch [390/623], Loss: 2.9041
# Epoch [1/20], Batch [400/623], Loss: 2.8428
# Epoch [1/20], Batch [410/623], Loss: 2.9031
# Epoch [1/20], Batch [420/623], Loss: 2.7485
# Epoch [1/20], Batch [430/623], Loss: 2.7151
# Epoch [1/20], Batch [440/623], Loss: 2.6302
# Epoch [1/20], Batch [450/623], Loss: 2.5594
# Epoch [1/20], Batch [460/623], Loss: 2.5926
# Epoch [1/20], Batch [470/623], Loss: 2.3960
# Epoch [1/20], Batch [480/623], Loss: 2.3970
# Epoch [1/20], Batch [490/623], Loss: 2.1694
# Epoch [1/20], Batch [500/623], Loss: 2.1026
# Epoch [1/20], Batch [510/623], Loss: 1.8711
# Epoch [1/20], Batch [520/623], Loss: 1.7920
# Epoch [1/20], Batch [530/623], Loss: 1.3599
# Epoch [1/20], Batch [540/623], Loss: 1.1335
# Epoch [1/20], Batch [550/623], Loss: 0.8451
# Epoch [1/20], Batch [560/623], Loss: 0.6109
# Epoch [1/20], Batch [570/623], Loss: 0.5350
# Epoch [1/20], Batch [580/623], Loss: 0.3580
# Epoch [1/20], Batch [590/623], Loss: 0.2095
# Epoch [1/20], Batch [600/623], Loss: 0.1747
# Epoch [1/20], Batch [610/623], Loss: 0.1869
# Epoch [1/20], Batch [620/623], Loss: 0.1635
# Epoch [1/20], Average Loss: 2.7668
# Epoch [2/20], Batch [0/623], Loss: 0.1561
# Epoch [2/20], Batch [10/623], Loss: 0.0882
# Epoch [2/20], Batch [20/623], Loss: 0.0835
# Epoch [2/20], Batch [30/623], Loss: 0.1102
# Epoch [2/20], Batch [40/623], Loss: 0.0608
# Epoch [2/20], Batch [50/623], Loss: 0.0814
# Epoch [2/20], Batch [60/623], Loss: 0.0634
# Epoch [2/20], Batch [70/623], Loss: 0.0446
# Epoch [2/20], Batch [80/623], Loss: 0.0565
# Epoch [2/20], Batch [90/623], Loss: 0.0642
# Epoch [2/20], Batch [100/623], Loss: 0.0370
# Epoch [2/20], Batch [110/623], Loss: 0.0393
# Epoch [2/20], Batch [120/623], Loss: 0.0351
# Epoch [2/20], Batch [130/623], Loss: 0.0339
# Epoch [2/20], Batch [140/623], Loss: 0.0281
# Epoch [2/20], Batch [150/623], Loss: 0.0402
# Epoch [2/20], Batch [160/623], Loss: 0.0376
# Epoch [2/20], Batch [170/623], Loss: 0.0481
# Epoch [2/20], Batch [180/623], Loss: 0.0272
# Epoch [2/20], Batch [190/623], Loss: 0.0364
# Epoch [2/20], Batch [200/623], Loss: 0.0178
# Epoch [2/20], Batch [210/623], Loss: 0.0251
# Epoch [2/20], Batch [220/623], Loss: 0.0149
# Epoch [2/20], Batch [230/623], Loss: 0.0174
# Epoch [2/20], Batch [240/623], Loss: 0.0121
# Epoch [2/20], Batch [250/623], Loss: 0.0106
# Epoch [2/20], Batch [260/623], Loss: 0.0145
# Epoch [4/20], Batch [80/623], Loss: 0.0025
# Epoch [4/20], Batch [90/623], Loss: 0.0025
# Epoch [4/20], Batch [100/623], Loss: 0.0026
# Epoch [4/20], Batch [110/623], Loss: 0.0049
# Epoch [4/20], Batch [120/623], Loss: 0.0026
# Epoch [4/20], Batch [130/623], Loss: 0.0158
# Epoch [4/20], Batch [140/623], Loss: 0.0017
# Epoch [4/20], Batch [150/623], Loss: 0.0025
# Epoch [4/20], Batch [160/623], Loss: 0.0021
# Epoch [4/20], Batch [170/623], Loss: 0.0020
# Epoch [4/20], Batch [180/623], Loss: 0.0011
# Epoch [4/20], Batch [190/623], Loss: 0.0013
# Epoch [4/20], Batch [200/623], Loss: 0.0026
# Epoch [4/20], Batch [210/623], Loss: 0.0031
# Epoch [4/20], Batch [220/623], Loss: 0.0017
# Epoch [4/20], Batch [230/623], Loss: 0.0016
# Epoch [4/20], Batch [240/623], Loss: 0.0026
# Epoch [4/20], Batch [250/623], Loss: 0.0011
# Epoch [4/20], Batch [260/623], Loss: 0.0018
# Epoch [4/20], Batch [270/623], Loss: 0.0022
# Epoch [4/20], Batch [280/623], Loss: 0.0012
# Epoch [4/20], Batch [290/623], Loss: 0.0049
# Epoch [4/20], Batch [300/623], Loss: 0.0040
# Epoch [4/20], Batch [310/623], Loss: 0.0016
# Epoch [4/20], Batch [320/623], Loss: 0.0014
# Epoch [4/20], Batch [330/623], Loss: 0.0010
# Epoch [4/20], Batch [340/623], Loss: 0.0011
# Epoch [4/20], Batch [350/623], Loss: 0.0008
# Epoch [4/20], Batch [360/623], Loss: 0.0008
# Epoch [4/20], Batch [370/623], Loss: 0.0011
# Epoch [4/20], Batch [380/623], Loss: 0.0019
# Epoch [4/20], Batch [390/623], Loss: 0.0013
# Epoch [4/20], Batch [400/623], Loss: 0.0010
# Epoch [4/20], Batch [410/623], Loss: 0.0023
# Epoch [4/20], Batch [420/623], Loss: 0.0140
# Epoch [4/20], Batch [430/623], Loss: 0.0066
# Epoch [4/20], Batch [440/623], Loss: 0.0013
# Epoch [4/20], Batch [450/623], Loss: 0.0012
# Epoch [4/20], Batch [460/623], Loss: 0.0013
# Epoch [4/20], Batch [470/623], Loss: 0.0190
# Epoch [4/20], Batch [480/623], Loss: 0.0038
# Epoch [4/20], Batch [490/623], Loss: 0.0119
# Epoch [4/20], Batch [500/623], Loss: 0.0059
# Epoch [4/20], Batch [510/623], Loss: 0.0083
# Epoch [4/20], Batch [520/623], Loss: 0.0017
# Epoch [4/20], Batch [530/623], Loss: 0.0024
# Epoch [4/20], Batch [540/623], Loss: 0.0213
# Epoch [4/20], Batch [550/623], Loss: 0.0189
# Epoch [4/20], Batch [560/623], Loss: 0.0050
# Epoch [4/20], Batch [570/623], Loss: 0.0191
# Epoch [4/20], Batch [580/623], Loss: 0.0081
# Epoch [4/20], Batch [590/623], Loss: 0.0028
# Epoch [4/20], Batch [600/623], Loss: 0.0028
# Epoch [4/20], Batch [610/623], Loss: 0.0023
# Epoch [4/20], Batch [620/623], Loss: 0.0011
# Epoch [4/20], Average Loss: 0.0047
# Epoch [5/20], Batch [0/623], Loss: 0.0018
# Epoch [5/20], Batch [10/623], Loss: 0.0025
# Epoch [5/20], Batch [20/623], Loss: 0.0010
# Epoch [5/20], Batch [30/623], Loss: 0.0011
# Epoch [5/20], Batch [40/623], Loss: 0.0017
# Epoch [5/20], Batch [50/623], Loss: 0.0044
# Epoch [5/20], Batch [60/623], Loss: 0.0012
# Epoch [5/20], Batch [70/623], Loss: 0.0012
# Epoch [5/20], Batch [80/623], Loss: 0.0018
# Epoch [5/20], Batch [90/623], Loss: 0.0012
# Epoch [5/20], Batch [100/623], Loss: 0.0009
# Epoch [5/20], Batch [110/623], Loss: 0.0008
# Epoch [5/20], Batch [120/623], Loss: 0.0033
# Epoch [5/20], Batch [130/623], Loss: 0.0032
# Epoch [5/20], Batch [140/623], Loss: 0.0006
# Epoch [5/20], Batch [150/623], Loss: 0.0007
# Epoch [5/20], Batch [160/623], Loss: 0.0011
# Epoch [5/20], Batch [170/623], Loss: 0.0012
# Epoch [5/20], Batch [180/623], Loss: 0.0009
# Epoch [5/20], Batch [190/623], Loss: 0.0011
# Epoch [5/20], Batch [200/623], Loss: 0.0005
# Epoch [5/20], Batch [210/623], Loss: 0.0019
# Epoch [5/20], Batch [220/623], Loss: 0.0009
# Epoch [5/20], Batch [230/623], Loss: 0.0008
# Epoch [5/20], Batch [240/623], Loss: 0.0005
# Epoch [5/20], Batch [250/623], Loss: 0.0005
# Epoch [5/20], Batch [260/623], Loss: 0.0005
# Epoch [5/20], Batch [270/623], Loss: 0.0004
# Epoch [5/20], Batch [280/623], Loss: 0.0003
# Epoch [5/20], Batch [290/623], Loss: 0.0005
# Epoch [5/20], Batch [300/623], Loss: 0.0007
# Epoch [5/20], Batch [310/623], Loss: 0.0005
# Epoch [5/20], Batch [320/623], Loss: 0.0004
# Epoch [5/20], Batch [330/623], Loss: 0.0013
# Epoch [5/20], Batch [340/623], Loss: 0.0005
# Epoch [5/20], Batch [350/623], Loss: 0.0007
# Epoch [5/20], Batch [360/623], Loss: 0.0013
# Epoch [5/20], Batch [370/623], Loss: 0.0005
# Epoch [5/20], Batch [380/623], Loss: 0.1441
# Epoch [5/20], Batch [390/623], Loss: 0.0099
# Epoch [5/20], Batch [400/623], Loss: 0.0126
# Epoch [5/20], Batch [410/623], Loss: 0.0190
# Epoch [5/20], Batch [420/623], Loss: 0.0158
# Epoch [5/20], Batch [430/623], Loss: 0.0091
# Epoch [5/20], Batch [440/623], Loss: 0.0045
# Epoch [5/20], Batch [450/623], Loss: 0.0150
# Epoch [5/20], Batch [460/623], Loss: 0.0032
# Epoch [5/20], Batch [470/623], Loss: 0.0016
# Epoch [5/20], Batch [480/623], Loss: 0.0010
# Epoch [5/20], Batch [490/623], Loss: 0.0016
# Epoch [5/20], Batch [500/623], Loss: 0.0006
# Epoch [5/20], Batch [510/623], Loss: 0.0014
# Epoch [5/20], Batch [520/623], Loss: 0.0016
# Epoch [7/20], Batch [350/623], Loss: 0.0002
# Epoch [7/20], Batch [360/623], Loss: 0.0002
# Epoch [7/20], Batch [370/623], Loss: 0.0002
# Epoch [7/20], Batch [380/623], Loss: 0.0003
# Epoch [7/20], Batch [390/623], Loss: 0.0002
# Epoch [7/20], Batch [400/623], Loss: 0.0002
# Epoch [7/20], Batch [410/623], Loss: 0.0003
# Epoch [7/20], Batch [420/623], Loss: 0.0006
# Epoch [7/20], Batch [430/623], Loss: 0.0017
# Epoch [7/20], Batch [440/623], Loss: 0.0017
# Epoch [7/20], Batch [450/623], Loss: 0.0010
# Epoch [7/20], Batch [460/623], Loss: 0.0006
# Epoch [7/20], Batch [470/623], Loss: 0.0004
# Epoch [7/20], Batch [480/623], Loss: 0.0006
# Epoch [7/20], Batch [490/623], Loss: 0.0010
# Epoch [7/20], Batch [500/623], Loss: 0.0067
# Epoch [7/20], Batch [510/623], Loss: 0.0095
# Epoch [7/20], Batch [520/623], Loss: 0.0058
# Epoch [7/20], Batch [530/623], Loss: 0.0035
# Epoch [7/20], Batch [540/623], Loss: 0.0020
# Epoch [7/20], Batch [550/623], Loss: 0.0009
# Epoch [7/20], Batch [560/623], Loss: 0.0015
# Epoch [7/20], Batch [570/623], Loss: 0.0056
# Epoch [7/20], Batch [580/623], Loss: 0.0015
# Epoch [7/20], Batch [590/623], Loss: 0.0009
# Epoch [7/20], Batch [600/623], Loss: 0.0017
# Epoch [7/20], Batch [610/623], Loss: 0.0015
# Epoch [7/20], Batch [620/623], Loss: 0.0009
# Epoch [7/20], Average Loss: 0.0015
# Epoch [8/20], Batch [0/623], Loss: 0.0013
# Epoch [8/20], Batch [10/623], Loss: 0.0007
# Epoch [8/20], Batch [20/623], Loss: 0.0009
# Epoch [8/20], Batch [30/623], Loss: 0.0114
# Epoch [8/20], Batch [40/623], Loss: 0.0052
# Epoch [8/20], Batch [50/623], Loss: 0.0024
# Epoch [8/20], Batch [60/623], Loss: 0.0042
# Epoch [8/20], Batch [70/623], Loss: 0.0064
# Epoch [8/20], Batch [80/623], Loss: 0.0027
# Epoch [8/20], Batch [90/623], Loss: 0.0074
# Epoch [8/20], Batch [100/623], Loss: 0.0038
# Epoch [8/20], Batch [110/623], Loss: 0.0038
# Epoch [8/20], Batch [120/623], Loss: 0.0008
# Epoch [8/20], Batch [130/623], Loss: 0.0009
# Epoch [8/20], Batch [140/623], Loss: 0.0004
# Epoch [8/20], Batch [150/623], Loss: 0.0003
# Epoch [8/20], Batch [160/623], Loss: 0.0016
# Epoch [8/20], Batch [170/623], Loss: 0.0008
# Epoch [8/20], Batch [180/623], Loss: 0.0005
# Epoch [8/20], Batch [190/623], Loss: 0.0009
# Epoch [8/20], Batch [200/623], Loss: 0.0004
# Epoch [8/20], Batch [210/623], Loss: 0.0191
# Epoch [8/20], Batch [220/623], Loss: 0.0003
# Epoch [8/20], Batch [230/623], Loss: 0.0004
# Epoch [8/20], Batch [240/623], Loss: 0.0002
# Epoch [8/20], Batch [250/623], Loss: 0.0003
# Epoch [8/20], Batch [260/623], Loss: 0.0025
# Epoch [8/20], Batch [270/623], Loss: 0.0006
# Epoch [8/20], Batch [280/623], Loss: 0.0020
# Epoch [8/20], Batch [290/623], Loss: 0.0006
# Epoch [8/20], Batch [300/623], Loss: 0.0002
# Epoch [8/20], Batch [310/623], Loss: 0.0002
# Epoch [8/20], Batch [320/623], Loss: 0.0004
# Epoch [8/20], Batch [330/623], Loss: 0.0006
# Epoch [8/20], Batch [340/623], Loss: 0.0006
# Epoch [8/20], Batch [350/623], Loss: 0.0002
# Epoch [8/20], Batch [360/623], Loss: 0.0007
# Epoch [8/20], Batch [370/623], Loss: 0.0002
# Epoch [8/20], Batch [380/623], Loss: 0.0001
# Epoch [8/20], Batch [390/623], Loss: 0.0001
# Epoch [8/20], Batch [400/623], Loss: 0.0002
# Epoch [8/20], Batch [410/623], Loss: 0.0008
# Epoch [8/20], Batch [420/623], Loss: 0.0001
# Epoch [8/20], Batch [430/623], Loss: 0.0002
# Epoch [8/20], Batch [440/623], Loss: 0.0007
# Epoch [8/20], Batch [450/623], Loss: 0.0009
# Epoch [8/20], Batch [460/623], Loss: 0.0016
# Epoch [8/20], Batch [470/623], Loss: 0.0022
# Epoch [8/20], Batch [480/623], Loss: 0.0004
# Epoch [8/20], Batch [490/623], Loss: 0.0085
# Epoch [8/20], Batch [500/623], Loss: 0.0003
# Epoch [8/20], Batch [510/623], Loss: 0.0019
# Epoch [8/20], Batch [520/623], Loss: 0.0019
# Epoch [8/20], Batch [530/623], Loss: 0.0051
# Epoch [8/20], Batch [540/623], Loss: 0.0112
# Epoch [8/20], Batch [550/623], Loss: 0.0012
# Epoch [8/20], Batch [560/623], Loss: 0.0042
# Epoch [8/20], Batch [570/623], Loss: 0.0012
# Epoch [8/20], Batch [580/623], Loss: 0.0022
# Epoch [8/20], Batch [590/623], Loss: 0.0041
# Epoch [8/20], Batch [600/623], Loss: 0.0039
# Epoch [8/20], Batch [610/623], Loss: 0.0031
# Epoch [8/20], Batch [620/623], Loss: 0.0013
# Epoch [8/20], Average Loss: 0.0038
# Epoch [9/20], Batch [0/623], Loss: 0.0052
# Epoch [9/20], Batch [10/623], Loss: 0.0032
# Epoch [9/20], Batch [20/623], Loss: 0.0016
# Epoch [9/20], Batch [30/623], Loss: 0.0006
# Epoch [9/20], Batch [40/623], Loss: 0.0015
# Epoch [9/20], Batch [50/623], Loss: 0.0005
# Epoch [9/20], Batch [60/623], Loss: 0.0015
# Epoch [9/20], Batch [70/623], Loss: 0.0003
# Epoch [9/20], Batch [80/623], Loss: 0.0003
# Epoch [9/20], Batch [90/623], Loss: 0.0012
# Epoch [9/20], Batch [100/623], Loss: 0.0003
# Epoch [9/20], Batch [110/623], Loss: 0.0007
# Epoch [9/20], Batch [120/623], Loss: 0.0002
# Epoch [9/20], Batch [130/623], Loss: 0.0002
# Epoch [9/20], Batch [140/623], Loss: 0.0005
# Epoch [9/20], Batch [150/623], Loss: 0.0002
# Epoch [9/20], Batch [160/623], Loss: 0.0005
# Epoch [10/20], Batch [70/623], Loss: 0.0001
# Epoch [10/20], Batch [80/623], Loss: 0.0001
# Epoch [10/20], Batch [90/623], Loss: 0.0005
# Epoch [10/20], Batch [100/623], Loss: 0.0002
# Epoch [10/20], Batch [110/623], Loss: 0.0001
# Epoch [10/20], Batch [120/623], Loss: 0.0002
# Epoch [10/20], Batch [130/623], Loss: 0.0122
# Epoch [10/20], Batch [140/623], Loss: 0.0045
# Epoch [10/20], Batch [150/623], Loss: 0.0002
# Epoch [10/20], Batch [160/623], Loss: 0.0013
# Epoch [10/20], Batch [170/623], Loss: 0.0002
# Epoch [10/20], Batch [180/623], Loss: 0.0003
# Epoch [10/20], Batch [190/623], Loss: 0.0002
# Epoch [10/20], Batch [200/623], Loss: 0.0010
# Epoch [10/20], Batch [210/623], Loss: 0.0002
# Epoch [10/20], Batch [220/623], Loss: 0.0009
# Epoch [10/20], Batch [230/623], Loss: 0.0001
# Epoch [10/20], Batch [240/623], Loss: 0.0003
# Epoch [10/20], Batch [250/623], Loss: 0.0001
# Epoch [10/20], Batch [260/623], Loss: 0.0001
# Epoch [10/20], Batch [270/623], Loss: 0.0002
# Epoch [10/20], Batch [280/623], Loss: 0.0001
# Epoch [10/20], Batch [290/623], Loss: 0.0001
# Epoch [10/20], Batch [300/623], Loss: 0.0005
# Epoch [10/20], Batch [310/623], Loss: 0.0001
# Epoch [10/20], Batch [320/623], Loss: 0.0003
# Epoch [10/20], Batch [330/623], Loss: 0.0002
# Epoch [10/20], Batch [340/623], Loss: 0.0001
# Epoch [10/20], Batch [350/623], Loss: 0.0002
# Epoch [10/20], Batch [360/623], Loss: 0.0001
# Epoch [10/20], Batch [370/623], Loss: 0.0001
# Epoch [10/20], Batch [380/623], Loss: 0.0000
# Epoch [10/20], Batch [390/623], Loss: 0.0001
# Epoch [10/20], Batch [400/623], Loss: 0.0001
# Epoch [10/20], Batch [410/623], Loss: 0.0001
# Epoch [10/20], Batch [420/623], Loss: 0.0001
# Epoch [10/20], Batch [430/623], Loss: 0.0001
# Epoch [10/20], Batch [440/623], Loss: 0.0001
# Epoch [10/20], Batch [450/623], Loss: 0.0001
# Epoch [10/20], Batch [460/623], Loss: 0.0000
# Epoch [10/20], Batch [470/623], Loss: 0.0000
# Epoch [10/20], Batch [480/623], Loss: 0.0000
# Epoch [10/20], Batch [490/623], Loss: 0.0025
# Epoch [10/20], Batch [500/623], Loss: 0.0005
# Epoch [10/20], Batch [510/623], Loss: 0.0010
# Epoch [10/20], Batch [520/623], Loss: 0.0001
# Epoch [10/20], Batch [530/623], Loss: 0.0001
# Epoch [10/20], Batch [540/623], Loss: 0.0002
# Epoch [10/20], Batch [550/623], Loss: 0.0001
# Epoch [10/20], Batch [560/623], Loss: 0.0001
# Epoch [10/20], Batch [570/623], Loss: 0.0001
# Epoch [10/20], Batch [580/623], Loss: 0.0003
# Epoch [10/20], Batch [590/623], Loss: 0.0001
# Epoch [10/20], Batch [600/623], Loss: 0.0001
# Epoch [10/20], Batch [610/623], Loss: 0.0001
# Epoch [16/20], Batch [70/623], Loss: 0.0002
# Epoch [16/20], Batch [80/623], Loss: 0.0002
# Epoch [16/20], Batch [90/623], Loss: 0.0001
# Epoch [16/20], Batch [100/623], Loss: 0.0001
# Epoch [16/20], Batch [110/623], Loss: 0.0000
# Epoch [16/20], Batch [120/623], Loss: 0.0010
# Epoch [16/20], Batch [130/623], Loss: 0.0002
# Epoch [16/20], Batch [140/623], Loss: 0.0000
# Epoch [16/20], Batch [150/623], Loss: 0.0003
# Epoch [16/20], Batch [160/623], Loss: 0.0002
# Epoch [16/20], Batch [170/623], Loss: 0.0003
# Epoch [16/20], Batch [180/623], Loss: 0.0000
# Epoch [16/20], Batch [190/623], Loss: 0.0000
# Epoch [16/20], Batch [200/623], Loss: 0.0055
# Epoch [16/20], Batch [210/623], Loss: 0.0001
# Epoch [16/20], Batch [220/623], Loss: 0.0003
# Epoch [16/20], Batch [230/623], Loss: 0.0001
# Epoch [16/20], Batch [240/623], Loss: 0.0004
# Epoch [16/20], Batch [250/623], Loss: 0.0002
# Epoch [16/20], Batch [260/623], Loss: 0.0006
# Epoch [16/20], Batch [270/623], Loss: 0.0002
# Epoch [16/20], Batch [280/623], Loss: 0.0001
# Epoch [16/20], Batch [290/623], Loss: 0.0001
# Epoch [16/20], Batch [300/623], Loss: 0.0004
# Epoch [16/20], Batch [310/623], Loss: 0.0010
# Epoch [16/20], Batch [320/623], Loss: 0.0001
# Epoch [16/20], Batch [330/623], Loss: 0.0006
# Epoch [16/20], Batch [340/623], Loss: 0.0001
# Epoch [16/20], Batch [350/623], Loss: 0.0001
# Epoch [16/20], Batch [360/623], Loss: 0.0001
# Epoch [16/20], Batch [370/623], Loss: 0.0217
# Epoch [16/20], Batch [380/623], Loss: 0.0359
# Epoch [16/20], Batch [390/623], Loss: 0.0024
# Epoch [16/20], Batch [400/623], Loss: 0.0002
# Epoch [16/20], Batch [410/623], Loss: 0.0016
# Epoch [16/20], Batch [420/623], Loss: 0.0001
# Epoch [16/20], Batch [430/623], Loss: 0.0001
# Epoch [16/20], Batch [440/623], Loss: 0.0001
# Epoch [16/20], Batch [450/623], Loss: 0.0001
# Epoch [16/20], Batch [460/623], Loss: 0.0001
# Epoch [16/20], Batch [470/623], Loss: 0.0001
# Epoch [16/20], Batch [480/623], Loss: 0.0001
# Epoch [16/20], Batch [490/623], Loss: 0.0004
# Epoch [16/20], Batch [500/623], Loss: 0.0002
# Epoch [16/20], Batch [510/623], Loss: 0.0084
# Epoch [16/20], Batch [520/623], Loss: 0.0005
# Epoch [16/20], Batch [530/623], Loss: 0.0005
# Epoch [16/20], Batch [540/623], Loss: 0.0001
# Epoch [16/20], Batch [550/623], Loss: 0.0001
# Epoch [16/20], Batch [560/623], Loss: 0.0000
# Epoch [16/20], Batch [570/623], Loss: 0.0002
# Epoch [16/20], Batch [580/623], Loss: 0.0001
# Epoch [16/20], Batch [590/623], Loss: 0.0000
# Epoch [16/20], Batch [600/623], Loss: 0.0001
# Epoch [20/20], Batch [240/623], Loss: 0.0000
# Epoch [20/20], Batch [250/623], Loss: 0.0000
# Epoch [20/20], Batch [260/623], Loss: 0.0001
# Epoch [20/20], Batch [270/623], Loss: 0.0000
# Epoch [20/20], Batch [280/623], Loss: 0.0000
# Epoch [20/20], Batch [290/623], Loss: 0.0000
# Epoch [20/20], Batch [300/623], Loss: 0.0000
# Epoch [20/20], Batch [310/623], Loss: 0.0078
# Epoch [20/20], Batch [320/623], Loss: 0.0000
# Epoch [20/20], Batch [330/623], Loss: 0.0000
# Epoch [20/20], Batch [340/623], Loss: 0.0000
# Epoch [20/20], Batch [350/623], Loss: 0.0000
# Epoch [20/20], Batch [360/623], Loss: 0.0000
# Epoch [20/20], Batch [370/623], Loss: 0.0001
# Epoch [20/20], Batch [380/623], Loss: 0.0000
# Epoch [20/20], Batch [390/623], Loss: 0.0000
# Epoch [20/20], Batch [400/623], Loss: 0.0001
# Epoch [20/20], Batch [410/623], Loss: 0.0000
# Epoch [20/20], Batch [420/623], Loss: 0.0001
# Epoch [20/20], Batch [430/623], Loss: 0.0000
# Epoch [20/20], Batch [440/623], Loss: 0.0000
# Epoch [20/20], Batch [450/623], Loss: 0.0000
# Epoch [20/20], Batch [460/623], Loss: 0.0000
# Epoch [20/20], Batch [470/623], Loss: 0.0000
# Epoch [20/20], Batch [480/623], Loss: 0.0000
# Epoch [20/20], Batch [490/623], Loss: 0.0000
# Epoch [20/20], Batch [500/623], Loss: 0.0000
# Epoch [20/20], Batch [510/623], Loss: 0.0000
# Epoch [20/20], Batch [520/623], Loss: 0.0000
# Epoch [20/20], Batch [530/623], Loss: 0.0000
# Epoch [20/20], Batch [540/623], Loss: 0.0000
# Epoch [20/20], Batch [550/623], Loss: 0.0000
# Epoch [20/20], Batch [560/623], Loss: 0.0000
# Epoch [20/20], Batch [570/623], Loss: 0.0000
# Epoch [20/20], Batch [580/623], Loss: 0.0000
# Epoch [20/20], Batch [590/623], Loss: 0.0000
# Epoch [20/20], Batch [600/623], Loss: 0.0000
# Epoch [20/20], Batch [610/623], Loss: 0.0000
# Epoch [20/20], Batch [620/623], Loss: 0.0000
# Epoch [20/20], Average Loss: 0.0002
# Model saved successfully.
# <All keys matched successfully>

# %% [markdown]
# ## Testing for easy dataset

# %%
generate_image(word="testing")
test_image_path= "testing.png"
predicted_text = predict_image(model, test_image_path, dataset.idx_to_label, device)
print("Predicted Text:", predicted_text)
# Out:
# Predicted Text: testing

# %%
import shutil

if os.path.exists("dataset/easy"):
    shutil.rmtree("dataset/easy")

if not os.path.exists("dataset"):
    os.makedirs("dataset")
if not os.path.exists("dataset/easy"):
    os.makedirs("dataset/easy")

def generate_random_images(words, image_path="dataset/easy"):
    # Generate and save an image for each word
    for word in words:
        # Assuming generate_image is a function that generates an image for the word
        generate_image(word)
        
        # Use the word as the filename (ensure it is not too long)
        image_file_path = os.path.join(image_path, f"{word}.png")
        
        # Save the image
        Image.open(f"{word}.png").save(image_file_path)

def test_model_accuracy(model, words, device, image_path="images/"):
    correct_predictions = 0

    # Generate random images for each word
    generate_random_images(words, image_path)

    for word in words:
        # Use the model to predict the word from the image
        test_image_path = os.path.join(image_path, f"{word}.png")
        predicted_text = predict_image(model, test_image_path, dataset.idx_to_label, device)

        # Check if the predicted text matches the word
        if predicted_text.lower() == word.lower():
            correct_predictions += 1

    accuracy = correct_predictions / len(words) * 100
    return accuracy

# Generate random words
words = generate_random_words(1000)

# Test the model accuracy
accuracy = test_model_accuracy(model, words, device)
print(f"Model Accuracy: {accuracy:.2f}%")
# Out:
# Model Accuracy: 99.60%

# %% [markdown]
# ## Train and Testing for hard dataset
#
# - rewrote the same code here for convenience, added RBG but doesn't matter beacuse of previosuly explained reasons.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from torchvision import transforms
from PIL import Image
import os
import numpy as np

def collate_fn(batch):
    images, labels, lengths = zip(*batch)
    images = torch.stack(images)
    max_len = max(lengths)
    padded_labels = torch.full((len(labels), max_len), fill_value=0, dtype=torch.long)
    for i, label in enumerate(labels):
        padded_labels[i, :len(label)] = label
    lengths = torch.tensor(lengths, dtype=torch.long)
    return images, padded_labels, lengths

class WordImageDataset(Dataset):
    def __init__(self, image_dir, transform=None):
        self.image_dir = image_dir
        self.transform = transform
        self.images = []
        self.labels = []
        self.label_to_idx = {'<blank>': 0}
        self.idx_to_label = {0: '<blank>'}
        chars = set()
        for filename in os.listdir(image_dir):
            if filename.endswith('.png'):
                word = filename.split('_')[0]
                chars.update(word)
        for idx, char in enumerate(sorted(chars), start=1):
            self.label_to_idx[char] = idx
            self.idx_to_label[idx] = char
        for filename in os.listdir(image_dir):
            if filename.endswith('.png'):
                word = filename.split('_')[0]
                char_indices = [self.label_to_idx[c] for c in word]
                self.images.append(os.path.join(image_dir, filename))
                self.labels.append(torch.tensor(char_indices, dtype=torch.long))
    def __len__(self):
        return len(self.images)
    def __getitem__(self, idx):
        image_path = self.images[idx]
        image = Image.open(image_path).convert('RGB')
        if self.transform:
            image = self.transform(image)
        label = self.labels[idx]
        length = len(label)
        return image, label, length

class CRNN(nn.Module):
    def __init__(self, num_classes, hidden_size=256):
        super(CRNN, self).__init__()
        self.cnn = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Conv2d(128, 256, kernel_size=3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d((2, 1)),
            nn.Conv2d(256, hidden_size, kernel_size=3, padding=1),
            nn.BatchNorm2d(hidden_size),
            nn.ReLU()
        )
        self.rnn = nn.LSTM(hidden_size, hidden_size, bidirectional=True, batch_first=True)
        self.fc = nn.Linear(hidden_size * 2, num_classes)
    def forward(self, x):
        conv = self.cnn(x)
        b, c, h, w = conv.size()
        conv = conv.view(b, c, -1)
        conv = conv.permute(0, 2, 1)
        rnn, _ = self.rnn(conv)
        output = self.fc(rnn)
        return output

def train_ocr_model(model, train_loader, criterion, optimizer, num_epochs=20, device='cuda'):
    model.to(device)
    for epoch in range(num_epochs):
        model.train()
        total_loss = 0
        for batch_idx, (images, targets, target_lengths) in enumerate(train_loader):
            images = images.to(device)
            targets = targets.to(device)
            target_lengths = target_lengths.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            batch_size = outputs.size(0)
            input_lengths = torch.full((batch_size,), outputs.size(1), dtype=torch.long).to(device)
            loss = criterion(outputs.log_softmax(2).permute(1, 0, 2), targets, input_lengths, target_lengths)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
            if batch_idx % 10 == 0:
                print(f'Epoch [{epoch+1}/{num_epochs}], Batch [{batch_idx}/{len(train_loader)}], Loss: {loss.item():.4f}')
        avg_loss = total_loss / len(train_loader)
        print(f'Epoch [{epoch+1}/{num_epochs}], Average Loss: {avg_loss:.4f}')
    torch.save(model.state_dict(), "crnn_model.pth")
    print("Model saved successfully.")

def decode_predictions(outputs, idx_to_label):
    _, predictions = outputs.max(2)
    predictions = predictions.cpu().numpy()
    decoded_words = []
    for pred in predictions:
        word = []
        prev_idx = -1
        for idx in pred:
            if idx != 0 and idx != prev_idx:
                word.append(idx_to_label[idx])
            prev_idx = idx
        decoded_words.append(''.join(word))
    return decoded_words

def preprocess_image(image_path):
    transform = transforms.Compose([
        transforms.Resize((32, 128)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
    ])
    image = Image.open(image_path).convert('RGB')
    image = transform(image).unsqueeze(0)
    return image

def predict_image(model, image_path, idx_to_label, device='cuda'):
    model.to(device)
    model.eval()
    image = preprocess_image(image_path).to(device)
    with torch.no_grad():
        output = model(image)
    predicted_text = decode_predictions(output, idx_to_label)
    return predicted_text[0]

if __name__ == "__main__":
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    transform = transforms.Compose([
        transforms.Resize((32, 128)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
    ])
    dataset = WordImageDataset('content/dataset/hard', transform=transform)
    train_loader = DataLoader(dataset, batch_size=32, shuffle=True, collate_fn=collate_fn)
    model = CRNN(num_classes=len(dataset.label_to_idx))
    criterion = nn.CTCLoss(zero_infinity=True)
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    train_ocr_model(model, train_loader, criterion, optimizer, device=device)
    model.load_state_dict(torch.load("crnn_model.pth"))
# Out:
# Epoch [1/20], Batch [0/311], Loss: 53.0280
# Epoch [1/20], Batch [10/311], Loss: 5.1527
# Epoch [1/20], Batch [20/311], Loss: 3.4116
# Epoch [1/20], Batch [30/311], Loss: 3.2314
# Epoch [1/20], Batch [40/311], Loss: 3.2566
# Epoch [1/20], Batch [50/311], Loss: 3.2195
# Epoch [1/20], Batch [60/311], Loss: 3.1520
# Epoch [1/20], Batch [70/311], Loss: 3.1574
# Epoch [1/20], Batch [80/311], Loss: 3.1222
# Epoch [1/20], Batch [90/311], Loss: 3.1806
# Epoch [1/20], Batch [100/311], Loss: 3.2106
# Epoch [1/20], Batch [110/311], Loss: 3.1607
# Epoch [1/20], Batch [120/311], Loss: 3.1689
# Epoch [1/20], Batch [130/311], Loss: 3.1424
# Epoch [1/20], Batch [140/311], Loss: 3.1862
# Epoch [1/20], Batch [150/311], Loss: 3.1909
# Epoch [1/20], Batch [160/311], Loss: 3.0745
# Epoch [1/20], Batch [170/311], Loss: 3.2101
# Epoch [1/20], Batch [180/311], Loss: 3.1638
# Epoch [1/20], Batch [190/311], Loss: 3.1880
# Epoch [1/20], Batch [200/311], Loss: 3.0706
# Epoch [1/20], Batch [210/311], Loss: 3.1426
# Epoch [1/20], Batch [220/311], Loss: 3.1534
# Epoch [1/20], Batch [230/311], Loss: 3.0916
# Epoch [1/20], Batch [240/311], Loss: 3.0498
# Epoch [1/20], Batch [250/311], Loss: 3.2132
# Epoch [1/20], Batch [260/311], Loss: 3.1485
# Epoch [1/20], Batch [270/311], Loss: 3.0550
# Epoch [1/20], Batch [280/311], Loss: 3.1285
# Epoch [1/20], Batch [290/311], Loss: 3.1887
# Epoch [1/20], Batch [300/311], Loss: 3.0550
# Epoch [1/20], Batch [310/311], Loss: 3.0567
# Epoch [1/20], Average Loss: 3.5802
# Epoch [2/20], Batch [0/311], Loss: 3.1397
# Epoch [2/20], Batch [10/311], Loss: 3.1663
# Epoch [2/20], Batch [20/311], Loss: 3.1216
# Epoch [2/20], Batch [30/311], Loss: 3.0812
# Epoch [2/20], Batch [40/311], Loss: 3.0791
# Epoch [2/20], Batch [50/311], Loss: 3.1416
# Epoch [2/20], Batch [60/311], Loss: 3.0668
# Epoch [2/20], Batch [70/311], Loss: 3.1452
# Epoch [2/20], Batch [80/311], Loss: 3.0204
# Epoch [2/20], Batch [90/311], Loss: 3.0354
# Epoch [2/20], Batch [100/311], Loss: 3.1319
# Epoch [2/20], Batch [110/311], Loss: 3.0349
# Epoch [2/20], Batch [120/311], Loss: 3.0469
# Epoch [2/20], Batch [130/311], Loss: 3.0614
# Epoch [20/20], Batch [240/311], Loss: 0.1006
# Epoch [20/20], Batch [250/311], Loss: 0.0035
# Epoch [20/20], Batch [260/311], Loss: 0.0050
# Epoch [20/20], Batch [270/311], Loss: 0.0187
# Epoch [20/20], Batch [280/311], Loss: 0.0145
# Epoch [20/20], Batch [290/311], Loss: 0.0110
# Epoch [20/20], Batch [300/311], Loss: 0.0314
# Epoch [20/20], Batch [310/311], Loss: 0.0790
# Epoch [20/20], Average Loss: 0.0246
# Model saved successfully.

# %%
## Actual testing for hard
generate_hard_image(word="testing")
test_image_path= "testing.png"
predicted_text = predict_image(model, test_image_path, dataset.idx_to_label, device)
print("Predicted Text:", predicted_text)
# Out:
# Predicted Text: restng

# %%
import shutil

if os.path.exists("dataset/hard"):
    shutil.rmtree("dataset/hard")

if not os.path.exists("dataset"):
    os.makedirs("dataset")
if not os.path.exists("dataset/hard"):
    os.makedirs("dataset/hard")

def generate_random_images(words, image_path="dataset/hard"):
    # Generate and save an image for each word
    for word in words:
        # Assuming generate_image is a function that generates an image for the word
        generate_image(word)
        
        # Use the word as the filename (ensure it is not too long)
        image_file_path = os.path.join(image_path, f"{word}.png")
        
        # Save the image
        Image.open(f"{word}.png").save(image_file_path)

def test_model_accuracy(model, words, device, image_path="images/"):
    correct_predictions = 0

    # Generate random images for each word
    generate_random_images(words, image_path)

    for word in words:
        # Use the model to predict the word from the image
        test_image_path = os.path.join(image_path, f"{word}.png")
        predicted_text = predict_image(model, test_image_path, dataset.idx_to_label, device)

        # Check if the predicted text matches the word
        if predicted_text.lower() == word.lower():
            correct_predictions += 1

    accuracy = correct_predictions / len(words) * 100
    return accuracy

# Generate random words
words = generate_random_words(1000)

# Test the model accuracy
accuracy = test_model_accuracy(model, words, device)
print(f"Model Accuracy: {accuracy:.2f}%")
# Out:
# Model Accuracy: 24.40%

# %% [markdown]
# ## Testing for Bonus dataset
#
# - rewrote the same code here for convenience

# %%
def collate_fn(batch):
    images, labels, lengths = zip(*batch)
    images = torch.stack(images)
    max_len = max(lengths)
    padded_labels = torch.full((len(labels), max_len), fill_value=0, dtype=torch.long)
    for i, label in enumerate(labels):
        padded_labels[i, :len(label)] = label
    lengths = torch.tensor(lengths, dtype=torch.long)
    return images, padded_labels, lengths

class WordImageDataset(Dataset):
    def __init__(self, image_dir, transform=None):
        self.image_dir = image_dir
        self.transform = transform
        self.images = []
        self.labels = []
        self.label_to_idx = {'<blank>': 0}
        self.idx_to_label = {0: '<blank>'}
        chars = set()
        for filename in os.listdir(image_dir):
            if filename.endswith('.png'):
                word = filename.split('_')[0]
                chars.update(word)
        for idx, char in enumerate(sorted(chars), start=1):
            self.label_to_idx[char] = idx
            self.idx_to_label[idx] = char
        for filename in os.listdir(image_dir):
            if filename.endswith('.png'):
                word = filename.split('_')[0]
                char_indices = [self.label_to_idx[c] for c in word]
                self.images.append(os.path.join(image_dir, filename))
                self.labels.append(torch.tensor(char_indices, dtype=torch.long))
    def __len__(self):
        return len(self.images)
    def __getitem__(self, idx):
        image_path = self.images[idx]
        image = Image.open(image_path).convert('RGB')
        if self.transform:
            image = self.transform(image)
        label = self.labels[idx]
        length = len(label)
        return image, label, length

class CRNN(nn.Module):
    def __init__(self, num_classes, hidden_size=256):
        super(CRNN, self).__init__()
        self.cnn = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Conv2d(128, 256, kernel_size=3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d((2, 1)),
            nn.Conv2d(256, hidden_size, kernel_size=3, padding=1),
            nn.BatchNorm2d(hidden_size),
            nn.ReLU()
        )
        self.rnn = nn.LSTM(hidden_size, hidden_size, bidirectional=True, batch_first=True)
        self.fc = nn.Linear(hidden_size * 2, num_classes)
    def forward(self, x):
        conv = self.cnn(x)
        b, c, h, w = conv.size()
        conv = conv.view(b, c, -1)
        conv = conv.permute(0, 2, 1)
        rnn, _ = self.rnn(conv)
        output = self.fc(rnn)
        return output

def train_ocr_model(model, train_loader, criterion, optimizer, num_epochs=20, device='cuda'):
    model.to(device)
    for epoch in range(num_epochs):
        model.train()
        total_loss = 0
        for batch_idx, (images, targets, target_lengths) in enumerate(train_loader):
            images = images.to(device)
            targets = targets.to(device)
            target_lengths = target_lengths.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            batch_size = outputs.size(0)
            input_lengths = torch.full((batch_size,), outputs.size(1), dtype=torch.long).to(device)
            loss = criterion(outputs.log_softmax(2).permute(1, 0, 2), targets, input_lengths, target_lengths)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
            if batch_idx % 10 == 0:
                print(f'Epoch [{epoch+1}/{num_epochs}], Batch [{batch_idx}/{len(train_loader)}], Loss: {loss.item():.4f}')
        avg_loss = total_loss / len(train_loader)
        print(f'Epoch [{epoch+1}/{num_epochs}], Average Loss: {avg_loss:.4f}')
    torch.save(model.state_dict(), "crnn_model.pth")
    print("Model saved successfully.")

def decode_predictions(outputs, idx_to_label):
    _, predictions = outputs.max(2)
    predictions = predictions.cpu().numpy()
    decoded_words = []
    for pred in predictions:
        word = []
        prev_idx = -1
        for idx in pred:
            if idx != 0 and idx != prev_idx:
                word.append(idx_to_label[idx])
            prev_idx = idx
        decoded_words.append(''.join(word))
    return decoded_words

def preprocess_image(image_path):
    transform = transforms.Compose([
        transforms.Resize((32, 128)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
    ])
    image = Image.open(image_path).convert('RGB')
    image = transform(image).unsqueeze(0)
    return image

def predict_image(model, image_path, idx_to_label, device='cuda'):
    model.to(device)
    model.eval()
    image = preprocess_image(image_path).to(device)
    with torch.no_grad():
        output = model(image)
    predicted_text = decode_predictions(output, idx_to_label)
    return predicted_text[0]

if __name__ == "__main__":
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    transform = transforms.Compose([
        transforms.Resize((32, 128)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
    ])
    dataset = WordImageDataset('content/dataset/bonus', transform=transform)
    train_loader = DataLoader(dataset, batch_size=32, shuffle=True, collate_fn=collate_fn)
    model = CRNN(num_classes=len(dataset.label_to_idx))
    criterion = nn.CTCLoss(zero_infinity=True)
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    train_ocr_model(model, train_loader, criterion, optimizer, device=device)
    model.load_state_dict(torch.load("crnn_model.pth"))
# Out:
# Epoch [1/20], Batch [0/311], Loss: 47.9432
# Epoch [1/20], Batch [10/311], Loss: 5.2826
# Epoch [1/20], Batch [20/311], Loss: 3.3528
# Epoch [1/20], Batch [30/311], Loss: 3.1932
# Epoch [1/20], Batch [40/311], Loss: 3.2909
# Epoch [1/20], Batch [50/311], Loss: 3.2842
# Epoch [1/20], Batch [60/311], Loss: 3.2847
# Epoch [1/20], Batch [70/311], Loss: 3.2310
# Epoch [1/20], Batch [80/311], Loss: 3.2638
# Epoch [1/20], Batch [90/311], Loss: 3.2020
# Epoch [1/20], Batch [100/311], Loss: 3.2001
# Epoch [1/20], Batch [110/311], Loss: 3.1556
# Epoch [1/20], Batch [120/311], Loss: 3.2204
# Epoch [1/20], Batch [130/311], Loss: 3.1527
# Epoch [1/20], Batch [140/311], Loss: 3.1933
# Epoch [1/20], Batch [150/311], Loss: 3.1952
# Epoch [1/20], Batch [160/311], Loss: 3.1147
# Epoch [1/20], Batch [170/311], Loss: 3.1610
# Epoch [1/20], Batch [180/311], Loss: 3.1804
# Epoch [1/20], Batch [190/311], Loss: 3.1771
# Epoch [1/20], Batch [200/311], Loss: 3.1334
# Epoch [1/20], Batch [210/311], Loss: 3.0811
# Epoch [19/20], Average Loss: 0.1686
# Epoch [20/20], Batch [0/311], Loss: 0.0780
# Epoch [20/20], Batch [10/311], Loss: 0.1101
# Epoch [20/20], Batch [20/311], Loss: 0.0970
# Epoch [20/20], Batch [30/311], Loss: 0.1112
# Epoch [20/20], Batch [40/311], Loss: 0.0827
# Epoch [20/20], Batch [50/311], Loss: 0.0757
# Epoch [20/20], Batch [60/311], Loss: 0.0696
# Epoch [20/20], Batch [70/311], Loss: 0.0715
# Epoch [20/20], Batch [80/311], Loss: 0.1074
# Epoch [20/20], Batch [90/311], Loss: 0.0756
# Epoch [20/20], Batch [100/311], Loss: 0.0992
# Epoch [20/20], Batch [110/311], Loss: 0.0894
# Epoch [20/20], Batch [120/311], Loss: 0.0936
# Epoch [20/20], Batch [130/311], Loss: 0.0838
# Epoch [20/20], Batch [140/311], Loss: 0.0976
# Epoch [20/20], Batch [150/311], Loss: 0.1428
# Epoch [20/20], Batch [160/311], Loss: 0.0769
# Epoch [20/20], Batch [170/311], Loss: 0.0959
# Epoch [20/20], Batch [180/311], Loss: 0.1024
# Epoch [20/20], Batch [190/311], Loss: 0.1201
# Epoch [20/20], Batch [200/311], Loss: 0.0854
# Epoch [20/20], Batch [210/311], Loss: 0.1207
# Epoch [20/20], Batch [220/311], Loss: 0.1721
# Epoch [20/20], Batch [230/311], Loss: 0.0936
# Epoch [20/20], Batch [240/311], Loss: 0.0784
# Epoch [20/20], Batch [250/311], Loss: 0.1516
# Epoch [20/20], Batch [260/311], Loss: 0.1209
# Epoch [20/20], Batch [270/311], Loss: 0.1205
# Epoch [20/20], Batch [280/311], Loss: 0.1343
# Epoch [20/20], Batch [290/311], Loss: 0.1595
# Epoch [20/20], Batch [300/311], Loss: 0.1173
# Epoch [20/20], Batch [310/311], Loss: 0.1414
# Epoch [20/20], Average Loss: 0.1074
# Model saved successfully.

# %%
# Actual testing for bonus dataset, randomly got an extra i, showing some limitations of the model

generate_bonus_image(word="testing")
test_image_path= "testing.png"
predicted_text = predict_image(model, test_image_path, dataset.idx_to_label, device)
print("Predicted Text:", predicted_text)
# Out:
# Predicted Text: tesiting

# %% [markdown]
# ## Test function for bonus dataset

# %%
def generate_random_images(words, image_path="images/"):
    # Generate and save an image for each word
    for word in words:
        # Assuming generate_image is a function that generates an image for the word
        generate_bonus_image(word)
        
        # Use the word as the filename (ensure it is not too long)
        image_file_path = os.path.join(image_path, f"{word}.png")
        
        # Save the image
        Image.open(f"{word}.png").save(image_file_path)

def test_model_accuracy(model, words, device, image_path="images/"):
    correct_predictions = 0

    # Generate random images for each word
    generate_random_images(words, image_path)

    for word in words:
        # Use the model to predict the word from the image
        test_image_path = os.path.join(image_path, f"{word}.png")
        predicted_text = predict_image(model, test_image_path, dataset.idx_to_label, device)

        # Check if the predicted text matches the word
        if predicted_text.lower() == word.lower():
            correct_predictions += 1

    accuracy = correct_predictions / len(words) * 100
    return accuracy

# Generate random words
words = generate_random_words(1000)

# Test the model accuracy
accuracy = test_model_accuracy(model, words, device)
print(f"Model Accuracy: {accuracy:.2f}%")
# Out:
# Model Accuracy: 44.00%
